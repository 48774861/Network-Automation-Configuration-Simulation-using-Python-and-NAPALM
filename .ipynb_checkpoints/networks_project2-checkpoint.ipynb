# %% [markdown]
# # Computer Networks Project 2
# William Miller, Marc Pham

# %% [markdown]
# ## Introduction

# %% [markdown]
# “This project simulates NAPALM-based network automation using Python classes to represent network devices. This allows us to demonstrate configuration management, state retrieval, and reporting without requiring physical or virtual routers.”

# %% [markdown]
# ## Motivation

# %% [markdown]
# Maybe add the capability of pinging other routers to see if all the IP addresses are configured correctly.

# %% [markdown]
# ## Methodology

# %%
# %pip install dash dash-cytoscape
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dash
#   Downloading dash-4.1.0-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 37.3 MB/s eta 0:00:00a 0:00:01
# Collecting dash-cytoscape
#   Downloading dash_cytoscape-1.0.2.tar.gz (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 41.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting Flask<3.2,>=1.0.4 (from dash)
#   Downloading flask-3.1.3-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: Werkzeug<3.2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from dash) (3.0.3)
# Collecting plotly>=5.0.0 (from dash)
#   Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 42.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: importlib-metadata in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from dash) (6.8.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: nest-asyncio in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from dash) (1.5.6)
# Requirement already satisfied: setuptools in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from dash) (58.0.4)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash)
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 15.6 MB/s eta 0:00:00
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from Flask<3.2,>=1.0.4->dash) (2.1.3)
# Collecting Werkzeug<3.2 (from dash)
#   Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from importlib-metadata->dash) (3.15.0)
# Collecting narwhals>=1.15.1 (from plotly>=5.0.0->dash)
#   Downloading narwhals-2.19.0-py3-none-any.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.0/447.0 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from plotly>=5.0.0->dash) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests->dash) (2024.6.2)
# Building wheels for collected packages: dash-cytoscape
#   Building wheel for dash-cytoscape (setup.py) ... one
#   Created wheel for dash-cytoscape: filename=dash_cytoscape-1.0.2-py3-none-any.whl size=4010735 sha256=7771ec9bb498f2606d389ca2bbb47c55bd354ffa79d60cac227322dec9e49a7a
#   Stored in directory: /Users/marcpham/Library/Caches/pip/wheels/7f/5d/69/48ee73398433d0efabd8521627493531f95cde3ab81805e0c1
# Successfully built dash-cytoscape
# Installing collected packages: Werkzeug, retrying, narwhals, itsdangerous, click, blinker, plotly, Flask, dash, dash-cytoscape
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.0.3
#     Uninstalling Werkzeug-3.0.3:
#       Successfully uninstalled Werkzeug-3.0.3
#   WARNING: The script plotly_get_chrome is installed in '/Users/marcpham/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask is installed in '/Users/marcpham/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dash-generate-components, dash-update-components, plotly and renderer are installed in '/Users/marcpham/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Flask-3.1.3 Werkzeug-3.1.8 blinker-1.9.0 click-8.1.8 dash-4.1.0 dash-cytoscape-1.0.2 itsdangerous-2.2.0 narwhals-2.19.0 plotly-6.7.0 retrying-1.4.2
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyvis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 14.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipython>=5.3.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from pyvis) (8.14.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from pyvis) (3.1.2)
# Collecting jsonpickle>=1.4.1 (from pyvis)
#   Downloading jsonpickle-4.1.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=1.11 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from pyvis) (3.2.1)
# Requirement already satisfied: backcall in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: typing-extensions in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (4.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.15.0)
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-4.1.1 pyvis-0.3.2
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install napalm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: napalm in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (5.1.0)
# Requirement already satisfied: setuptools>=38.4.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from napalm) (58.0.4)
# Requirement already satisfied: cffi>=1.11.3 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (2.0.0)
# Requirement already satisfied: paramiko>=2.6.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (4.0.0)
# Requirement already satisfied: requests>=2.7.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (2.32.3)
# Requirement already satisfied: textfsm in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (2.1.0)
# Requirement already satisfied: jinja2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (3.1.2)
# Requirement already satisfied: netaddr in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (1.3.0)
# Requirement already satisfied: pyYAML in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (6.0.3)
# Requirement already satisfied: pyeapi>=1.0.2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (1.0.4)
# Requirement already satisfied: netmiko>=4.4.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (4.6.0)
# Requirement already satisfied: junos-eznc>=2.7.4 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (2.7.6)
# Requirement already satisfied: lxml>=4.3.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (6.0.4)
# Requirement already satisfied: ncclient in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (0.7.0)
# Requirement already satisfied: ttp in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (0.10.1)
# Requirement already satisfied: ttp_templates in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (0.3.7)
# Requirement already satisfied: netutils>=1.0.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (1.15.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from napalm) (4.15.0)
# Requirement already satisfied: pycparser in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from cffi>=1.11.3->napalm) (2.21)
# Requirement already satisfied: scp>=0.7.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from junos-eznc>=2.7.4->napalm) (0.15.0)
# Requirement already satisfied: six in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from junos-eznc>=2.7.4->napalm) (1.15.0)
# Requirement already satisfied: pyserial in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from junos-eznc>=2.7.4->napalm) (3.5)
# Requirement already satisfied: yamlloader in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from junos-eznc>=2.7.4->napalm) (1.6.0)
# Requirement already satisfied: pyparsing in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from junos-eznc>=2.7.4->napalm) (3.0.9)
# Requirement already satisfied: transitions in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from junos-eznc>=2.7.4->napalm) (0.9.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from jinja2->napalm) (2.1.3)
# Requirement already satisfied: ntc-templates>=3.1.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from netmiko>=4.4.0->napalm) (8.1.0)
# Requirement already satisfied: rich>=13.8 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from netmiko>=4.4.0->napalm) (15.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from netmiko>=4.4.0->napalm) (0.19.1)
# Requirement already satisfied: bcrypt>=3.2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from paramiko>=2.6.0->napalm) (5.0.0)
# Requirement already satisfied: cryptography>=3.3 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from paramiko>=2.6.0->napalm) (46.0.7)
# Requirement already satisfied: invoke>=2.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from paramiko>=2.6.0->napalm) (3.0.3)
# Requirement already satisfied: pynacl>=1.5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from paramiko>=2.6.0->napalm) (1.6.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests>=2.7.0->napalm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests>=2.7.0->napalm) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests>=2.7.0->napalm) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from requests>=2.7.0->napalm) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from rich>=13.8->netmiko>=4.4.0->napalm) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from rich>=13.8->netmiko>=4.4.0->napalm) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/marcpham/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=13.8->netmiko>=4.4.0->napalm) (0.1.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from napalm import get_network_driver
import time
import json
import os
from IPython.display import display, HTML, IFrame
import networkx as nx
import matplotlib.pyplot as plt
import ipaddress
from pyvis.network import Network
import dash
from dash import html
import dash_cytoscape as cyto

# %%
class driver:
    def __init__(self, hostname):
        self.hostname = hostname
        self.running_config = []
        self.candidate_config = []

        self.interfaces = {
            "eth0": {"is_up": True, "ip": None},
            "eth1": {"is_up": True, "ip": None},
        }

# %%
def load_merge_candidate(self, config):
    print(f"\n[{self.hostname}] load_merge_candidate()")
    self.candidate_config = config

driver.load_merge_candidate = load_merge_candidate

# %%
def compare_config(self):
    print(f"[{self.hostname}] compare_config()")

    diff = []

    for line in self.candidate_config:
        if line not in self.running_config:
            diff.append(f"+ {line}")

    for line in self.running_config:
        if line not in self.candidate_config:
            diff.append(f"- {line}")

    return "\n".join(diff)

driver.compare_config = compare_config

# %%
def commit_config(self):
    print(f"[{self.hostname}] commit_config()")

    self.running_config = self.candidate_config.copy()

    current_interface = None

    for line in self.candidate_config:
        parts = line.strip().split()

        if len(parts) == 0:
            continue

        if parts[0] == "interface":
            current_interface = parts[1]

            if current_interface not in self.interfaces:
                self.interfaces[current_interface] = {
                    "is_up": True,
                    "ip": None
                }

        elif len(parts) >= 3 and parts[0] == "ip" and parts[1] == "address":
            if current_interface:
                self.interfaces[current_interface]["ip"] = parts[2]

def discard_config(self):
    print(f"[{self.hostname}] discard_config()")
    self.candidate_config = []
    
driver.commit_config = commit_config
driver.discard_config = discard_config

# %%
def get_facts(self):
    return {
        "hostname": self.hostname,
        "vendor": "mock_napalm_driver",
        "config_lines": len(self.running_config),
    }

def get_interfaces(self):
    return self.interfaces

driver.get_facts = get_facts
driver.get_interfaces = get_interfaces

# %%
# ==============================
# CONFIG LOADER
# ==============================
def load_device_configs(filename):
    try:
        base_dir = os.path.dirname(os.path.abspath(__file__))
    except NameError:
        base_dir = os.getcwd()  # fallback for notebooks/interactive mode

    file_path = os.path.join(base_dir, filename)

    with open(file_path, "r") as f:
        return json.load(f)

def build_config(device_data):
    config = []

    config.append(f"hostname {device_data['hostname']}")

    for intf, ip in device_data["interfaces"].items():
        config.append(f"interface {intf}")
        if ip:
            config.append(f"ip address {ip}")

    return config

# %%
def provision_devices(devices, config_file):
    configs = load_device_configs(config_file)

    print("\n===== PROVISIONING DEVICES =====")

    for name, data in configs.items():
        device = devices[name]

        config_lines = build_config(data)

        device.load_merge_candidate(config_lines)

        diff = device.compare_config()

        print(f"\n[{name}] CONFIG DIFF:")
        print(diff if diff else "No changes")

        if diff:
            device.commit_config()
        else:
            device.discard_config()

# %%
def generate_report(devices, output_file="network_report.json"):

    report = {}
    for name, device in devices.items():
        report[name] = {
            "facts": device.get_facts(),
            "interfaces": device.get_interfaces()
        }

    with open(output_file, "w") as f:
        json.dump(report, f, indent=4)

# %%
def build_network_graph(config_file, draw=True):
    try:
        base_dir = os.path.dirname(os.path.abspath(__file__))
    except NameError:
        base_dir = os.getcwd()

    file_path = os.path.join(base_dir, config_file)

    with open(file_path, "r") as f:
        configs = json.load(f)

    G = nx.Graph()
    subnet_map = {}

    # Step 1: Build subnet membership
    for device_name, data in configs.items():
        G.add_node(device_name, type="device")

        for intf, ip in data["interfaces"].items():
            if not ip:
                continue

            iface = ipaddress.ip_interface(ip)
            network = str(iface.network)

            subnet_map.setdefault(network, []).append(
                (device_name, intf, str(iface.ip))
            )

    # Step 2: Build graph
    for network, members in subnet_map.items():

        if len(members) == 1:
            # Create a "LAN node"
            device, intf, ip = members[0]

            lan_node = f"{network}"
            G.add_node(lan_node, type="network")

            G.add_edge(
                device,
                lan_node,
                interface=intf,
                ip=ip
            )

        else:
            # Normal device-to-device links
            for i in range(len(members)):
                for j in range(i + 1, len(members)):
                    d1, i1, ip1 = members[i]
                    d2, i2, ip2 = members[j]

                    G.add_edge(
                        d1,
                        d2,
                        network=network,
                        interfaces=f"{i1} ↔ {i2}",
                        ips=f"{ip1} ↔ {ip2}"
                    )

    # Step 3: Draw
    if draw:
        plt.figure(figsize=(12, 8), dpi=150)

        pos = nx.spring_layout(G, seed=42, k=2, iterations = 300)

        # Separate node types
        device_nodes = [n for n, d in G.nodes(data=True) if d["type"] == "device"]
        network_nodes = [n for n, d in G.nodes(data=True) if d["type"] == "network"]

        # Draw devices
        nx.draw_networkx_nodes(
            G, pos,
            nodelist=device_nodes,
            node_color="skyblue",
            node_size=1000,
            label="Devices"
        )

        # Draw networks (LANs)
        nx.draw_networkx_nodes(
            G, pos,
            nodelist=network_nodes,
            node_color="lightgreen",
            node_shape="s",
            node_size=1000,
            label="Networks"
        )

        # Draw edges
        nx.draw_networkx_edges(G, pos, edge_color="gray")

        # Labels
        nx.draw_networkx_labels(G, pos, font_size=7, font_weight="bold")

        # Edge labels
        # Edge labels (clean format: eth0: 10.0.0.1/30)
        edge_labels = {}
        
        for u, v, data in G.edges(data=True):
        
            key = tuple(sorted([u, v]))
        
            if "network" not in data:
                iface = data.get("interface", "")
                ip = data.get("ip", "")
                edge_labels[key] = f"{ip}"
        
            else:
                iface_pair = data.get("interfaces", "")
                ip_pair = data.get("ips", "")
        
                # split and label both sides cleanly
                if "↔" in iface_pair and "↔" in ip_pair:
                    i1, i2 = iface_pair.split("↔")
                    p1, p2 = ip_pair.split("↔")

                    edge_labels[(u, v)] = f"{u} ({p1.strip()}) ↔ {v} ({p2.strip()})"
                else:
                    edge_labels[(u, v)] = data.get("network", "")

        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=9)

        plt.title("Network Topology", fontsize=16)
        plt.legend(
            loc='upper right',
            fontsize=14,
            markerscale=0.8,
            borderpad=1.5,
            labelspacing=1.2
        )
        plt.tight_layout(rect=[0, 0.05, 1, 1])
        plt.show()

    return G

# %%
def render_network_cytoscape(G):

    elements = []

    # -------------------------
    # NODES
    # -------------------------
    for node, data in G.nodes(data=True):

        if data.get("type") == "device":
            color = "skyblue"
            shape = "ellipse"
        else:
            color = "lightgreen"
            shape = "rectangle"

        elements.append({
            "data": {
                "id": node,
                "label": node
            },
            "style": {
                "background-color": color,
                "shape": shape
            }
        })

    # -------------------------
    # EDGES
    # -------------------------
    for u, v, data in G.edges(data=True):

        if "network" not in data:
            label = data.get("ip", "")
        else:
            iface_pair = data.get("interfaces", "")
            ip_pair = data.get("ips", "")

            if "↔" in iface_pair and "↔" in ip_pair:
                i1, i2 = iface_pair.split("↔")
                p1, p2 = ip_pair.split("↔")
                label = f"{u} ({p1.strip()}) ↔ {v} ({p2.strip()})"
            else:
                label = data.get("network", "")

        elements.append({
            "data": {
                "source": u,
                "target": v,
                "label": label
            }
        })

    # -------------------------
    # APP
    # -------------------------
    app = dash.Dash(__name__)

    app.layout = html.Div([
        cyto.Cytoscape(
            id="network",
            elements=elements,
            layout={
                "name": "cose",   # force-directed but stable
                "animate": False
            },
            style={"width": "100%", "height": "800px"},
            stylesheet=[
                {
                    "selector": "node",
                    "style": {
                        "label": "data(label)",
                        "font-size": "10px",
                        "text-valign": "center",
                        "text-halign": "center",
                        "color": "black"
                    }
                },
                {
                    "selector": "edge",
                    "style": {
                        "label": "data(label)",
                        "font-size": "8px",
                        "color": "black",
                
                        "text-background-color": "white",
                        "text-background-opacity": 1,
                        "text-background-padding": "3px",
                        "text-border-color": "#cccccc",
                        "text-border-width": "1px",
                        "text-border-opacity": 1,
                
                        "line-color": "#888",
                        "curve-style": "bezier"
                    }
                }
            ]
        )
    ])

    app.run(debug=False)

# %% [markdown]
# ## Short Demonstration

# %% [markdown]
# This topology represents a simple hybrid network design with a core point-to-point backbone and two access networks. The link between R1 and R2 uses the 10.0.0.0/30 subnet, which is typically used for router-to-router connections because it provides exactly two usable IP addresses, one for each router interface. In addition to the backbone, each router connects to a separate /24 access network: R1 connects to the 192.168.1.0/24 subnet and R2 connects to the 192.168.2.0/24 subnet. These larger subnets represent local LAN segments or edge networks where end devices such as PCs or servers would reside. Overall, this design demonstrates a basic enterprise-style architecture with a structured separation between the core inter-router link and the access layer networks.

# %%
G = build_network_graph("device_config1.json")

devices = {}
for node, data in G.nodes(data=True):
    if data.get("type") == "device":
        devices[node] = driver(hostname=node)

# Provision devices
provision_devices(devices, "device_config1.json")

print("\n===== NETWORK REPORT =====")

for name, device in devices.items():
    print(f"\n--- {name} ---")
    print("FACTS:")
    display(device.get_facts())

    print("\nINTERFACES:")
    display(device.get_interfaces())

# Generate report
generate_report(devices, "network_report1.json")
# Out:
# ===== PROVISIONING DEVICES =====
#
# [R1] load_merge_candidate()
# [R1] compare_config()
#
# [R1] CONFIG DIFF:
# + hostname R1
# + interface eth0
# + ip address 10.0.0.1/30
# + interface eth1
# + ip address 192.168.1.1/24
# [R1] commit_config()
#
# [R2] load_merge_candidate()
# [R2] compare_config()
#
# [R2] CONFIG DIFF:
# + hostname R2
# + interface eth0
# + ip address 10.0.0.2/30
# + interface eth1
# + ip address 192.168.2.1/24
# [R2] commit_config()
#
# ===== NETWORK REPORT =====
#
# --- R1 ---
# FACTS:
# {'hostname': 'R1', 'vendor': 'mock_napalm_driver', 'config_lines': 5}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.1/30'},
#  'eth1': {'is_up': True, 'ip': '192.168.1.1/24'}}
# --- R2 ---
# FACTS:
# {'hostname': 'R2', 'vendor': 'mock_napalm_driver', 'config_lines': 5}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.2/30'},
#  'eth1': {'is_up': True, 'ip': '192.168.2.1/24'}}

# %%
render_network_cytoscape(G)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The backbone network is divided into multiple /30 subnets, each representing a point-to-point link between two routers. Each /30 subnet provides four addresses: a network address, two usable IPs (assigned to the connected routers), and a broadcast address. For example, the...
# - 10.0.0.0/30 subnet connects R1 and R2 using 10.0.0.1 and 10.0.0.2
# - 10.0.0.4/30 subnet connectes R2 and R3 with usable addresses 10.0.0.5 and 10.0.0.6
# - 10.0.0.8/30 subnet connects R3 and R4 with usable addresses 10.0.0.9 and 10.0.0.10
# - 10.0.0.12/30 subnet connects R4 and R1 with usable addresses 10.0.0.13 and 10.0.0.14
#
# This design ensures that each router-to-router link is isolated in its own subnet, optimizing IP usage and reflecting standard practices for point-to-point backbone connections. For the access / edge layer, let's assign the IP addresses, like so:
# * 192.168.1.0/24 subnet connects R1 and R5 using 192.168.1.1 and 192.168.1.2
# * 192.168.2.0/24 subnet connects R1 and R6 using 192.168.2.1 and 192.168.2.2
# * 192.168.3.0/24 subnet connects R2 and R7 using 192.168.3.1 and 192.168.3.2
# * 192.168.4.0/24 subnet connects R2 and R8 using 192.168.4.1 and 192.168.4.2
# * 192.168.5.0/24 subnet connects R3 and R9 using 192.168.5.1 and 192.168.5.2
# * 192.168.6.0/24 subnet connects R3 and R10 using 192.168.6.1 and 192.168.6.2
# * 192.168.7.0/24 subnet connects R4 and R11 using 192.168.7.1 and 192.168.7.2
# * 192.168.8.0/24 subnet connects R4 and R12 using 192.168.8.1 and 192.168.8.2

# %%
G = build_network_graph("device_config2.json")

devices = {}
for node, data in G.nodes(data=True):
    if data.get("type") == "device":
        devices[node] = driver(hostname=node)

# Provision devices
provision_devices(devices, "device_config2.json")
generate_report(devices)

# Show live device state (important for demo proof)
print("LIVE DEVICE STATE CHECK")

for name, device in devices.items():
    print(f"\n--- {name} ---")
    print("FACTS:")
    display(device.get_facts())

    print("\nINTERFACES:")
    display(device.get_interfaces())

# Generate report
generate_report(devices, "network_report2.json")
# Out:
# ===== PROVISIONING DEVICES =====
#
# [R1] load_merge_candidate()
# [R1] compare_config()
#
# [R1] CONFIG DIFF:
# + hostname R1-Core
# + interface eth0
# + ip address 10.0.0.1/30
# + interface eth1
# + ip address 10.0.0.14/30
# + interface eth2
# + ip address 192.168.1.1/24
# + interface eth3
# + ip address 192.168.2.1/24
# [R1] commit_config()
#
# [R2] load_merge_candidate()
# [R2] compare_config()
#
# [R2] CONFIG DIFF:
# + hostname R2-Core
# + interface eth0
# + ip address 10.0.0.2/30
# + interface eth1
# + ip address 10.0.0.5/30
# + interface eth2
# + ip address 192.168.3.1/24
# + interface eth3
# + ip address 192.168.4.1/24
# [R2] commit_config()
#
# [R3] load_merge_candidate()
# [R3] compare_config()
#
# [R3] CONFIG DIFF:
# + hostname R3-Core
# + interface eth0
# + ip address 10.0.0.6/30
# + interface eth1
# + ip address 10.0.0.9/30
# + interface eth2
# + ip address 192.168.5.1/24
# + interface eth3
# + ip address 192.168.6.1/24
# [R3] commit_config()
#
# [R4] load_merge_candidate()
# [R4] compare_config()
#
# [R4] CONFIG DIFF:
# + hostname R4-Core
# + interface eth0
# + ip address 10.0.0.10/30
# + interface eth1
# + ip address 10.0.0.13/30
# + interface eth2
# + ip address 192.168.7.1/24
# + interface eth3
# + ip address 192.168.8.1/24
# [R4] commit_config()
#
# [R5] load_merge_candidate()
# [R5] compare_config()
#
# [R5] CONFIG DIFF:
# + hostname R5-Edge
# + interface eth0
# + ip address 192.168.1.2/24
# [R5] commit_config()
#
# [R6] load_merge_candidate()
# [R6] compare_config()
#
# [R6] CONFIG DIFF:
# + hostname R6-Edge
# + interface eth0
# + ip address 192.168.2.2/24
# [R6] commit_config()
#
# [R7] load_merge_candidate()
# [R7] compare_config()
#
# [R7] CONFIG DIFF:
# + hostname R7-Edge
# + interface eth0
# + ip address 192.168.3.2/24
# [R7] commit_config()
#
# [R8] load_merge_candidate()
# [R8] compare_config()
#
# [R8] CONFIG DIFF:
# + hostname R8-Edge
# + interface eth0
# + ip address 192.168.4.2/24
# [R8] commit_config()
#
# [R9] load_merge_candidate()
# [R9] compare_config()
#
# [R9] CONFIG DIFF:
# + hostname R9-Edge
# + interface eth0
# + ip address 192.168.5.2/24
# [R9] commit_config()
#
# [R10] load_merge_candidate()
# [R10] compare_config()
#
# [R10] CONFIG DIFF:
# + hostname R10-Edge
# + interface eth0
# + ip address 192.168.6.2/24
# [R10] commit_config()
#
# [R11] load_merge_candidate()
# [R11] compare_config()
#
# [R11] CONFIG DIFF:
# + hostname R11-Edge
# + interface eth0
# + ip address 192.168.7.2/24
# [R11] commit_config()
#
# [R12] load_merge_candidate()
# [R12] compare_config()
#
# [R12] CONFIG DIFF:
# + hostname R12-Edge
# + interface eth0
# + ip address 192.168.8.2/24
# [R12] commit_config()
# LIVE DEVICE STATE CHECK
#
# --- R1 ---
# FACTS:
# {'hostname': 'R1', 'vendor': 'mock_napalm_driver', 'config_lines': 9}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.1/30'},
#  'eth1': {'is_up': True, 'ip': '10.0.0.14/30'},
#  'eth2': {'is_up': True, 'ip': '192.168.1.1/24'},
#  'eth3': {'is_up': True, 'ip': '192.168.2.1/24'}}
# --- R2 ---
# FACTS:
# {'hostname': 'R2', 'vendor': 'mock_napalm_driver', 'config_lines': 9}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.2/30'},
#  'eth1': {'is_up': True, 'ip': '10.0.0.5/30'},
#  'eth2': {'is_up': True, 'ip': '192.168.3.1/24'},
#  'eth3': {'is_up': True, 'ip': '192.168.4.1/24'}}
# --- R3 ---
# FACTS:
# {'hostname': 'R3', 'vendor': 'mock_napalm_driver', 'config_lines': 9}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.6/30'},
#  'eth1': {'is_up': True, 'ip': '10.0.0.9/30'},
#  'eth2': {'is_up': True, 'ip': '192.168.5.1/24'},
#  'eth3': {'is_up': True, 'ip': '192.168.6.1/24'}}
# --- R4 ---
# FACTS:
# {'hostname': 'R4', 'vendor': 'mock_napalm_driver', 'config_lines': 9}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '10.0.0.10/30'},
#  'eth1': {'is_up': True, 'ip': '10.0.0.13/30'},
#  'eth2': {'is_up': True, 'ip': '192.168.7.1/24'},
#  'eth3': {'is_up': True, 'ip': '192.168.8.1/24'}}
# --- R5 ---
# FACTS:
# {'hostname': 'R5', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.1.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R6 ---
# FACTS:
# {'hostname': 'R6', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.2.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R7 ---
# FACTS:
# {'hostname': 'R7', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.3.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R8 ---
# FACTS:
# {'hostname': 'R8', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.4.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R9 ---
# FACTS:
# {'hostname': 'R9', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.5.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R10 ---
# FACTS:
# {'hostname': 'R10', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.6.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R11 ---
# FACTS:
# {'hostname': 'R11', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.7.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}
# --- R12 ---
# FACTS:
# {'hostname': 'R12', 'vendor': 'mock_napalm_driver', 'config_lines': 3}
# INTERFACES:
# {'eth0': {'is_up': True, 'ip': '192.168.8.2/24'},
#  'eth1': {'is_up': True, 'ip': None}}

# %% [markdown]
# ## Summary and Conclusion

# %% [markdown]
# ## Distribution of Work
